# %% [markdown]
# ### Import packages, prepare data for S3

# %%
import os
import boto3
import pandas as pd
import numpy as np
import s3fs
from datetime import datetime
import time
import sagemaker
from sagemaker.estimator import Estimator
from sagemaker import image_uris
from sagemaker.inputs import TrainingInput
from sagemaker.debugger import Rule, rule_configs, ProfilerRule
from sagemaker.tuner import HyperparameterTuner, IntegerParameter, CategoricalParameter, ContinuousParameter
from sagemaker.analytics import HyperparameterTuningJobAnalytics
from IPython.display import FileLink, FileLinks
from sagemaker.predictor import csv_serializer

# %%
### configure S3
role = sagemaker.get_execution_role()
bucket = 'udacity-mle-capstone-starbucks'
prefix = 'xgboost'
sess = sagemaker.Session()
region = sess._region_name
print (region)
# Out:
# us-east-1

# %%
### read train and test data
df_train = pd.read_csv('data/df_train.csv')
df_test = pd.read_csv('data/df_test.csv')

# %%
### process as readable input for xgboost
def process_for_xgb(df):
    df.drop(columns=['person','time','offer_id'],inplace=True)
    df_new = pd.concat([df['target'], df.drop('target',axis=1)],axis=1)
    return df_new

# %%
df_train_xgb = process_for_xgb(df_train)
df_test_xgb = process_for_xgb(df_test)

# %%
for name, dataset in zip(["train", "test"], [df_train_xgb, df_test_xgb]):
    sess.upload_string_as_file_body(body=dataset.to_csv(index=False, header=False),
                                   bucket=bucket,
                                   key=f"{prefix}/input/{name}.csv"
                                   )
                                   
# configure data inputs for SageMaker training
train_input = TrainingInput(f"s3://{bucket}/{prefix}/input/train.csv", content_type="text/csv")
validation_input = TrainingInput(f"s3://{bucket}/{prefix}/input/test.csv", content_type="text/csv")

# %% [markdown]
# ### Set up parameters, estimator, and tuner

# %%
rules=[
    Rule.sagemaker(rule_configs.create_xgboost_report()),
    ProfilerRule.sagemaker(rule_configs.ProfilerReport()),
]

# %%
xgboost_container = image_uris.retrieve("xgboost", region, "1.2-1")

estimator=Estimator(
    role=role,
    image_uri=xgboost_container,
    base_job_name="xgb_starbucks_hpo",
    instance_count=1,
    instance_type="ml.m5.xlarge",
    output_path=f's3://{bucket}/{prefix}/output/',
#     hyperparameters=hyperparameters,
#     rules=rules, 
)

estimator.set_hyperparameters(    
    max_depth = 6,
    eta = 0.1,
    objective='binary:logistic',
    num_round=100,
    eval_metric='auc')

hyperparameter_ranges = {'eta': ContinuousParameter(0.01,1.0),
                         'max_depth': IntegerParameter(5, 10),
                        'num_round': IntegerParameter(50, 200)
                        }

tuner = HyperparameterTuner(estimator,
                    objective_metric_name='validation:auc',
                    hyperparameter_ranges=hyperparameter_ranges,
                    max_parallel_jobs=10,
                    max_jobs=60)

# %%
tuner.fit({'train': train_input, 'validation': validation_input}, 
              wait=True)
# Out:
# No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config
# No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config
# .............................................

# %%
#### Describe the tuning results
exp = HyperparameterTuningJobAnalytics(
  hyperparameter_tuning_job_name='sagemaker-xgboost-230419-0834')
jobs = exp.dataframe()
jobs.sort_values('FinalObjectiveValue', ascending=0)
# Out:
#          eta  max_depth  num_round  \
# 16  0.079036        5.0      142.0
# 19  0.073204        5.0      148.0
# 15  0.068235        5.0      169.0
# 23  0.068231        5.0      168.0
# 13  0.060062        6.0      145.0
# 5   0.067329        5.0      155.0
# 39  0.067962        6.0      124.0
# 6   0.060664        6.0      146.0
# 20  0.074913        5.0      174.0
# 0   0.070127        5.0      162.0
# 26  0.076552        5.0      166.0
# 10  0.069285        5.0      179.0
# 21  0.071343        5.0      148.0
# 49  0.113593        5.0      111.0
# 7   0.065209        5.0      168.0
# 27  0.081437        5.0      180.0
# 9   0.062454        6.0      151.0
# 12  0.061822        6.0      138.0
# 22  0.053730        5.0      187.0
# 17  0.081294        5.0      154.0
# 11  0.064545        5.0      172.0
# 8   0.065194        5.0      158.0
# 18  0.076146        5.0      152.0
# 25  0.058858        5.0      185.0
# 3   0.066721        5.0      161.0
# 4   0.071759        5.0      149.0
# 24  0.087650        5.0      144.0
# 2   0.074489        5.0      187.0
# 28  0.074475        5.0      198.0
# 43  0.032151        7.0      178.0
# 14  0.068387        6.0      138.0
# 48  0.156651        5.0      110.0
# 1   0.066147        5.0      157.0
# 37  0.059631        5.0      113.0
# 35  0.039566        7.0      196.0
# 42  0.039743        7.0      120.0
# 32  0.058440        7.0      190.0
# 34  0.041539        8.0      196.0
# 33  0.055932        7.0      185.0
# 31  0.036522        8.0      187.0
# 30  0.039101        8.0      199.0
# 29  0.057400        7.0      200.0
# 38  0.082062        5.0       58.0
# 58  0.023272        9.0      109.0
# 36  0.061139        5.0       67.0
# 40  0.027166       10.0      137.0
# 56  0.328285        5.0      104.0
# 41  0.022685        9.0       83.0
# 57  0.277943        6.0      115.0
# 46  0.359265        5.0      109.0
# 47  0.031571        5.0      111.0
# 45  0.010000       10.0      187.0
# 44  0.021539       10.0       69.0
# 59  0.199908        9.0      120.0
# 52  0.652482        5.0       60.0
# 55  0.344180        8.0       72.0
# 50  0.766834        5.0       58.0
# 51  0.745752        6.0       53.0
# 54  0.532141       10.0      118.0
# 53  0.560227       10.0       71.0
#
#                                TrainingJobName TrainingJobStatus  \
# 16  sagemaker-xgboost-230419-0834-044-826ad614         Completed
# 19  sagemaker-xgboost-230419-0834-041-cfea97ed         Completed
# 15  sagemaker-xgboost-230419-0834-045-a7773391         Completed
# 23  sagemaker-xgboost-230419-0834-037-28ffc1e1         Completed
# 13  sagemaker-xgboost-230419-0834-047-09e9b8c3         Completed
# 5   sagemaker-xgboost-230419-0834-055-be08eb5b         Completed
# 39  sagemaker-xgboost-230419-0834-021-ca3c6c80         Completed
# 6   sagemaker-xgboost-230419-0834-054-a49381f0         Completed
# 20  sagemaker-xgboost-230419-0834-040-db081ceb         Completed
# 0   sagemaker-xgboost-230419-0834-060-a9b3b1da         Completed
# 26  sagemaker-xgboost-230419-0834-034-f0424ed6         Completed
# 10  sagemaker-xgboost-230419-0834-050-de01a42b         Completed
# 21  sagemaker-xgboost-230419-0834-039-95a57ce3         Completed
# 49  sagemaker-xgboost-230419-0834-011-475af335         Completed
# 7   sagemaker-xgboost-230419-0834-053-5fefe178         Completed
# 27  sagemaker-xgboost-230419-0834-033-1bedecdd         Completed
# 9   sagemaker-xgboost-230419-0834-051-2f806efc         Completed
# 12  sagemaker-xgboost-230419-0834-048-e28e28c4         Completed
# 22  sagemaker-xgboost-230419-0834-038-33eefe9a         Completed
# 2023-04-19 08:41:57 Completed - Resource reused by training job: sagemaker-xgboost-230419-0834-054-a49381f0

# %%
best_estimator.hyperparameters()
# Out:
# {'_tuning_objective_metric': 'validation:auc',
#  'eta': '0.07903618528752897',
#  'eval_metric': 'auc',
#  'max_depth': '5',
#  'num_round': '142',
#  'objective': 'binary:logistic'}

# %%
hyperparameters = { 'eta': '0.07903618528752897',
                 'max_depth': '5',
                 'num_round': '142',
                 'objective': 'binary:logistic'
                        }

# %%
estimator=Estimator(
    role=role,
    image_uri=xgboost_container,
    base_job_name="xgb-starbucks-clf",
    instance_count=1,
    instance_type="ml.m5.xlarge",
    output_path=f's3://{bucket}/{prefix}/output/',
    hyperparameters=hyperparameters,
    rules=rules, 
)
# Out:
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole

# %%
estimator.fit({'train': train_input, 'validation': validation_input}, 
              wait=True)
# Out:
# INFO:sagemaker:Creating training-job with name: xgb-starbucks-clf-2023-04-19-11-42-41-675
# 2023-04-19 11:42:41 Starting - Starting the training job...
# 2023-04-19 11:43:07 Starting - Preparing the instances for trainingCreateXgboostReport: InProgress
# ProfilerReport: InProgress
# ...
# 2023-04-19 11:43:42 Downloading - Downloading input data...
# 2023-04-19 11:44:07 Training - Downloading the training image...
# 2023-04-19 11:44:38 Training - Training image download completed. Training in progress...[2023-04-19 11:44:49.952 ip-10-0-250-218.ec2.internal:7 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Single node training.
# [2023-04-19 11:44:50.073 ip-10-0-250-218.ec2.internal:7 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-04-19 11:44:50.074 ip-10-0-250-218.ec2.internal:7 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-04-19 11:44:50.074 ip-10-0-250-218.ec2.internal:7 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2023-04-19 11:44:50.075 ip-10-0-250-218.ec2.internal:7 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2023-04-19 11:44:50.075 ip-10-0-250-218.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# INFO:root:Debug hook created from config
# INFO:root:Train matrix has 49896 rows and 21 columns
# INFO:root:Validation matrix has 12475 rows
# [0]#011train-error:0.26251#011validation-error:0.26677
# [2023-04-19 11:44:50.149 ip-10-0-250-218.ec2.internal:7 INFO hook.py:413] Monitoring the collections: labels, predictions, feature_importance, metrics, hyperparameters
# [2023-04-19 11:44:50.150 ip-10-0-250-218.ec2.internal:7 INFO hook.py:476] Hook is writing from the hook with pid: 7
# [1]#011train-error:0.25834#011validation-error:0.26212
# [2]#011train-error:0.25842#011validation-error:0.26204
# [3]#011train-error:0.25802#011validation-error:0.26124
# [4]#011train-error:0.25816#011validation-error:0.26068
# [5]#011train-error:0.25611#011validation-error:0.25732
# [6]#011train-error:0.25575#011validation-error:0.25739
# [7]#011train-error:0.25535#011validation-error:0.25555
# [8]#011train-error:0.25489#011validation-error:0.25443
# [9]#011train-error:0.25489#011validation-error:0.25379
# [10]#011train-error:0.25397#011validation-error:0.25315
# [11]#011train-error:0.25267#011validation-error:0.25315
# [12]#011train-error:0.25255#011validation-error:0.25323
# [13]#011train-error:0.25166#011validation-error:0.25266
# [14]#011train-error:0.25114#011validation-error:0.25274
# [15]#011train-error:0.25068#011validation-error:0.25178
# [16]#011train-error:0.25026#011validation-error:0.25074
# [17]#011train-error:0.25020#011validation-error:0.25130
# [18]#011train-error:0.24976#011validation-error:0.25050
# [19]#011train-error:0.24934#011validation-error:0.25010
# [20]#011train-error:0.24870#011validation-error:0.24962
# [21]#011train-error:0.24832#011validation-error:0.25042
# [22]#011train-error:0.24687#011validation-error:0.24778
# [23]#011train-error:0.24609#011validation-error:0.24705
# [24]#011train-error:0.24537#011validation-error:0.24585
# [25]#011train-error:0.24465#011validation-error:0.24505
# [26]#011train-error:0.24393#011validation-error:0.24441
# [27]#011train-error:0.24263#011validation-error:0.24505
# [28]#011train-error:0.24286#011validation-error:0.24433
# [29]#011train-error:0.24238#011validation-error:0.24425
# [30]#011train-error:0.24234#011validation-error:0.24313
# [31]#011train-error:0.24206#011validation-error:0.24297
# [32]#011train-error:0.24196#011validation-error:0.24241
# [33]#011train-error:0.24048#011validation-error:0.24289
# [34]#011train-error:0.23922#011validation-error:0.24264
# [35]#011train-error:0.23892#011validation-error:0.24144
# [36]#011train-error:0.23769#011validation-error:0.24136
# [37]#011train-error:0.23683#011validation-error:0.24104
# [38]#011train-error:0.23663#011validation-error:0.24040
# [39]#011train-error:0.23581#011validation-error:0.24016
# [40]#011train-error:0.23567#011validation-error:0.23992
# [41]#011train-error:0.23541#011validation-error:0.23976
# [42]#011train-error:0.23527#011validation-error:0.23984
# [43]#011train-error:0.23513#011validation-error:0.23936
# [44]#011train-error:0.23455#011validation-error:0.23944
# [45]#011train-error:0.23445#011validation-error:0.23968
# [46]#011train-error:0.23365#011validation-error:0.23968
# [47]#011train-error:0.23334#011validation-error:0.23928
# [48]#011train-error:0.23276#011validation-error:0.23848
# [49]#011train-error:0.23228#011validation-error:0.23808
# [50]#011train-error:0.23214#011validation-error:0.23872
# [51]#011train-error:0.23186#011validation-error:0.23880
# [52]#011train-error:0.23170#011validation-error:0.23808
# [53]#011train-error:0.23166#011validation-error:0.23792
# [54]#011train-error:0.23138#011validation-error:0.23792
# [55]#011train-error:0.23114#011validation-error:0.23784
# [56]#011train-error:0.23102#011validation-error:0.23760
# [57]#011train-error:0.23090#011validation-error:0.23687
# [58]#011train-error:0.23050#011validation-error:0.23695
# [59]#011train-error:0.23038#011validation-error:0.23671
# [60]#011train-error:0.23060#011validation-error:0.23687
# [61]#011train-error:0.23010#011validation-error:0.23647
# [62]#011train-error:0.22970#011validation-error:0.23695
# [63]#011train-error:0.22948#011validation-error:0.23663
# [64]#011train-error:0.22914#011validation-error:0.23591
# [65]#011train-error:0.22902#011validation-error:0.23567
# [66]#011train-error:0.22884#011validation-error:0.23495
# [67]#011train-error:0.22820#011validation-error:0.23503
# [68]#011train-error:0.22805#011validation-error:0.23543
# [69]#011train-error:0.22805#011validation-error:0.23551
# [70]#011train-error:0.22781#011validation-error:0.23567
# [71]#011train-error:0.22749#011validation-error:0.23487
# [72]#011train-error:0.22757#011validation-error:0.23503
# [73]#011train-error:0.22741#011validation-error:0.23503
# [74]#011train-error:0.22733#011validation-error:0.23399
# [75]#011train-error:0.22711#011validation-error:0.23423
# [76]#011train-error:0.22717#011validation-error:0.23415
# [77]#011train-error:0.22705#011validation-error:0.23327
# [78]#011train-error:0.22685#011validation-error:0.23391
# [79]#011train-error:0.22675#011validation-error:0.23367
# [80]#011train-error:0.22681#011validation-error:0.23351
# [81]#011train-error:0.22639#011validation-error:0.23359
# [82]#011train-error:0.22661#011validation-error:0.23343
# [83]#011train-error:0.22643#011validation-error:0.23311
# [84]#011train-error:0.22643#011validation-error:0.23319
# [85]#011train-error:0.22649#011validation-error:0.23295
# [86]#011train-error:0.22631#011validation-error:0.23255
# [87]#011train-error:0.22601#011validation-error:0.23279
# [88]#011train-error:0.22599#011validation-error:0.23295
# [89]#011train-error:0.22579#011validation-error:0.23262
# [90]#011train-error:0.22565#011validation-error:0.23270
# [91]#011train-error:0.22541#011validation-error:0.23198
# [92]#011train-error:0.22535#011validation-error:0.23182
# [93]#011train-error:0.22507#011validation-error:0.23231
# [94]#011train-error:0.22529#011validation-error:0.23174
# [95]#011train-error:0.22517#011validation-error:0.23174
# [96]#011train-error:0.22485#011validation-error:0.23182
# [97]#011train-error:0.22453#011validation-error:0.23190
# [98]#011train-error:0.22435#011validation-error:0.23214
# [99]#011train-error:0.22439#011validation-error:0.23182
# [100]#011train-error:0.22439#011validation-error:0.23166
# [101]#011train-error:0.22439#011validation-error:0.23174
# [102]#011train-error:0.22433#011validation-error:0.23142
# [103]#011train-error:0.22417#011validation-error:0.23134
# [104]#011train-error:0.22403#011validation-error:0.23150
# [105]#011train-error:0.22397#011validation-error:0.23142
# [106]#011train-error:0.22391#011validation-error:0.23126
# [107]#011train-error:0.22376#011validation-error:0.23110
# [108]#011train-error:0.22389#011validation-error:0.23150
# [109]#011train-error:0.22367#011validation-error:0.23134
# [110]#011train-error:0.22365#011validation-error:0.23134
# [111]#011train-error:0.22368#011validation-error:0.23142
# [112]#011train-error:0.22330#011validation-error:0.23086
# [113]#011train-error:0.22320#011validation-error:0.23054
# [114]#011train-error:0.22304#011validation-error:0.23022
# [115]#011train-error:0.22306#011validation-error:0.23030
# [116]#011train-error:0.22288#011validation-error:0.23014
# [117]#011train-error:0.22286#011validation-error:0.22998
# [118]#011train-error:0.22260#011validation-error:0.22998
# [119]#011train-error:0.22258#011validation-error:0.22990
# [120]#011train-error:0.22248#011validation-error:0.22982
# [121]#011train-error:0.22226#011validation-error:0.22982
# [122]#011train-error:0.22198#011validation-error:0.23022
# [123]#011train-error:0.22178#011validation-error:0.22950
# [124]#011train-error:0.22160#011validation-error:0.22990
# [125]#011train-error:0.22164#011validation-error:0.22990
# [126]#011train-error:0.22160#011validation-error:0.22998
# [127]#011train-error:0.22166#011validation-error:0.22966
# [128]#011train-error:0.22126#011validation-error:0.22982
# [129]#011train-error:0.22118#011validation-error:0.22990
# [130]#011train-error:0.22112#011validation-error:0.22982
# [131]#011train-error:0.22098#011validation-error:0.23014
# [132]#011train-error:0.22088#011validation-error:0.22998
# [133]#011train-error:0.22078#011validation-error:0.22998
# [134]#011train-error:0.22080#011validation-error:0.23014
# [135]#011train-error:0.22066#011validation-error:0.23038
# [136]#011train-error:0.22060#011validation-error:0.23038
# [137]#011train-error:0.22050#011validation-error:0.23038
# [138]#011train-error:0.22044#011validation-error:0.23038
# [139]#011train-error:0.22030#011validation-error:0.23038
# [140]#011train-error:0.22034#011validation-error:0.23046
# [141]#011train-error:0.22022#011validation-error:0.23006
#
# 2023-04-19 11:45:08 Uploading - Uploading generated training model
# 2023-04-19 11:45:28 Completed - Training job completed
# Training seconds: 92
# Billable seconds: 92

# %% [markdown]
# ### Check training report

# %%
# get profiler report and training report from S3
profiler_report_name = [rule["RuleConfigurationName"] 
                        for rule in estimator.latest_training_job.rule_job_summary() 
                        if "Profiler" in rule["RuleConfigurationName"]][0]

xgb_profile_job_name = [rule["RuleEvaluationJobArn"].split("/")[-1] 
                        for rule in estimator.latest_training_job.rule_job_summary() 
                        if "CreateXgboostReport" in rule["RuleConfigurationName"]][0]

base_output_path = os.path.dirname(estimator.latest_job_debugger_artifacts_path())
rule_output_path = os.path.join(base_output_path, "rule-output/")
xgb_report_path = os.path.join(rule_output_path, "CreateXgboostReport")
profile_report_path = os.path.join(rule_output_path, profiler_report_name)

while True:
    
    xgb_job_info = sess.sagemaker_client.describe_processing_job(ProcessingJobName=xgb_profile_job_name)

    if xgb_job_info["ProcessingJobStatus"] == "Completed":
        break
    else:
        print(f"Job Status: {xgb_job_info['ProcessingJobStatus']}")
        time.sleep(30)

s3.download(xgb_report_path, "reports/xgb/", recursive=True)
s3.download(profile_report_path, "reports/profiler/", recursive=True)
display("Click link below to view the profiler report", FileLink("reports/profiler/profiler-output/profiler-report.html"))
display("Click link below to view the XGBoost Training report", FileLink("reports/xgb/xgboost_report.html"))
# Out:
# Job Status: InProgress
# Job Status: InProgress
# Job Status: InProgress
# Job Status: InProgress
# Job Status: InProgress
# 'Click link below to view the profiler report'
# /home/ec2-user/SageMaker/reports/profiler/profiler-output/profiler-report.html
# 'Click link below to view the XGBoost Training report'
# /home/ec2-user/SageMaker/reports/xgb/xgboost_report.html

# %%
# in training report, the most 3 important features are f1, f5, f20, then f12, f4
features = df_train_xgb.columns[1:].values

# %%
print ("The most 3 important features are:{}, {}, {}".format(features[1],features[5],features[20]) )
print ("{} and {} are also important feature".format(features[12],features[4]))
# Out:
# The most 3 important features are:total_amount, reward, success_rate
# discount and member_duration are also important feature

# %% [markdown]
# ### Deploy model and test

# %%
xgb_predictor = estimator.deploy(initial_instance_count=1,instance_type='ml.m5.large')
# Out:
# INFO:sagemaker:Creating model with name: xgb-starbucks-clf-2023-04-19-12-00-00-852
# INFO:sagemaker:Creating endpoint-config with name xgb-starbucks-clf-2023-04-19-12-00-00-852
# INFO:sagemaker:Creating endpoint with name xgb-starbucks-clf-2023-04-19-12-00-00-852
# ------!

# %%
xgb_predictor.endpoint_name
# Out:
# 'xgb-starbucks-clf-2023-04-19-12-00-00-852'

# %%
# create predictor
xgb_predictor=sagemaker.predictor.RealTimePredictor(
    "xgb-starbucks-clf-2023-04-19-12-00-00-852", 
    sagemaker_session=sess,
    serializer=csv_serializer,
    content_type='text/csv')

# make inference
output = xgb_predictor.predict(df_test_xgb.iloc[-3:, 1:].values).decode('utf-8')
# Out:
# WARNING:sagemaker.deprecations:The class RealTimePredictor has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# WARNING:sagemaker.deprecations:content_type is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# WARNING:sagemaker.deprecations:The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
### convert to label
[int(float(x)>0.5) for x in output.split(',')]
# Out:
# [1, 0, 1]

# %%
### actual target
df_test_xgb.iloc[-3:, 0].values
# Out:
# array([1, 0, 1])
